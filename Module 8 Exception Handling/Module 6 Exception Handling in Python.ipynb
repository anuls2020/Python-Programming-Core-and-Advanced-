# %% [markdown]
# <h1><center>Excepion Handling in Python</center></h1>

# %% [markdown]
# ### <font color='#3498DB'>Index</font>

# %% [markdown]
# 1. <font color='#3498DB'>**Purpose of Excepion Handling**</font>
# 2. <font color='#3498DB'>**What is Exception**</font>
# 3. <font color='#3498DB'>**What is Exception Handling**</font>
# 4. <font color='#3498DB'>**Points to be remembered in Exception Handling**</font>
# 5. <font color='#3498DB'>**What happen internally when the exception occurs**</font>
# 6. <font color='#3498DB'>**Types of Exceptions**</font>
#     * <font color='#009900'>**Pre-Defined Exceptions/Builtin Exceptions**</font>
#     * <font color='#009900'>**Programmer-Defined Exceptions**</font>
# 7. <font color='#3498DB'>**Handling the Exceptions in Python**</font>
# 8. <font color='#3498DB'>**Keywords required for Excepion Handling**</font>
#     * <font color='#009900'>**try**</font>
#     * <font color='#009900'>**except**</font>
#     * <font color='#009900'>**else**</font>
#     * <font color='#009900'>**finally**</font>
#     * <font color='#009900'>**raise**</font>
# 9. <font color='#3498DB'>**Syntax for handling the Exceptions**</font>
# 10. <font color='#3498DB'>**Explanation for the keywords used in Syntax for handling the exceptions**</font>
# 11. <font color='#3498DB'>**Development of Prorgammer defined Exceptions**</font>
# 12. <font color='#3498DB'>**Programming Examples**</font>
# 13. <font color='#3498DB'>**Case Study -- ATM Applicaion**</font>

# %% [markdown]
# ### <font color='#3498DB'>**Pyrpose of Exception Handling**</font>

# %% [markdown]
# * The purpose of Exception handling is to <font color='#009900'>**Develop Robust(Strong) Appliations**</font>.
#
# * In Real time, To develop any project, we need to choose a Language.  And by using that language we can **develop**, **Compile** & **Execute** various programs.
# * During this process we may get **3-Types** of errors. They are,
#     1. <font color='#009900'>**Compile Time Error**</font>
#     2. <font color='#009900'>**Logical Error**</font>
#     3. <font color='#009900'>**Runtime Error**</font>
#
# #####  <font color='#3498DB'>**1. Compile Time Error**</font>
#    * Compile time errors are those, which are occurring at compile time(**.py  --> .pyc**)
#    * Compile time errors are occurring due to <font color='#009900'>**Syntaxes are not followed**</font> by the programmer.
#    * These errors are solved by the Programmers at development level.
#
#
# ##### <font color='#3498DB'>**2. Logical Error**</font>
#    * Logical errors are those which are <font color='#009900'>**occurring during execution time**</font>.
#     ![logical%20error-2.PNG](attachment:logical%20error-2.PNG)
#
#    * Logical Errors are occurring due to <font color='#009900'>**wrong representation of Logic**</font>.
#    * Logical Errors always give **wrong results/inconsistant results**
#    * These errors solved by Programmer during Development Time.
#
#
# ##### <font color='#3498DB'>**3. Runtime Error**</font>
#    * Runtime errors are those, which are **occurring at execution time**.
#    * Runtime errors are occurring due to <font color='#009900'>**wrong input or invalid input entered by application user or end users**</font>.
#    * Runtime errors must be **handled by programmer during development time with forcasting knowledge**.

# %% [markdown]
# ### <font color='#3498DB'>**Definition of Exception**</font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Every Runtime Error is called Exception.</b><br>
#
# <b>`Invalid Input --> Runtime Error --> Exception`</b>
# </div>

# %% [markdown]
# ### <font color='#3498DB'>**Definition of Exception Handling**</font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>The Purpose of converting "Technical Error Message" into "User Friendly Error Messages" is called Exception Handling.</b>
# </div>

# %% [markdown]
# ### <font color='#3498DB'>**Points to be remembered in Exception Handling**</font>

# %% [markdown]
# * When the application or end user enters a wrong input/invalid input, then we get **Runtime Error**
# * Runtime errors by default given **Technical Error Messages**. These messages are understandable by Programmers but not by the end users. Industry always recommends, convert the **Technical Error Messages** in to **User friendly Error Messages** by using <font color='#009900'>**"Excepotion Handling"**</font>.
# * Every exception by default gives **Technical Error Message**.

# %% [markdown]
# ### <font color='#3498DB'>What happen internally when the exception occurs</font>

# %% [markdown]
# * When exception occurs in Python Program, Three steps take place internally.They are
#
#   a. PVM **terminate the program execution** abnormally.</br>
#   b. PVM **comes out of the program flow** without executing rest of the statements.</br>
#   c. PVM by default **generates Technical Error Message**.</br>
#
# * To do the steps a,b and c, PVM create an object of appropriate exception classes.
# * Hence every **Invalid Input** given **Exception** and **Every Exception** is treated as **Object** and is created w.r.t appropriate exception classes.
#
#    <font color='#009900'>**Invalid Input --> Exception --> Object --> Appropriate Exception Classes**</font>

# %% [markdown]
# ### <font color='#3498DB'>Types of Exceptions</font>

# %% [markdown]
# * In Python, We have two type of Exceptions,They are,
#     1. <font color='#009900'>**Pre-Defined / Built-in Exceptions**</font>
#     2. <font color='#009900'>**Programmer / User / Custom-defined Exceptions**</font>

# %% [markdown]
# #### <font color='#3498DB'>**Pre-Defined / Built-in Exceptions**</font>

# %% [markdown]
# * Pre-defined / Built-in Exceptions are developed by Python Language Developers and they are available in Python API(Library) and whos role is to deal with Universal problems.
# * Someof the Universal Problems are
#   * a) Division by Zero Problems ( <font color='#009900'>**ZeroDivisionError**</font>)
#   * b) Invalid number formats ( <font color='#009900'>**ValueError**</font>)
#   * c) Invalid arguments / Operations (<font color='#009900'>**TypeError**</font>)
#   * d) searching the value of value in in dict by passing invalid key  (<font color='#009900'>**KeyError**</font>)
#   * e) Invalid Variable Names (<font color='#009900'>**NameError**</font>)......etc

# %% [markdown]
# #### <font color='#3498DB'>**Programmer / User / Custom-defined Exceptions**</font>

# %% [markdown]
# * Programmer / User / Custom-defined Exceptions  are developed by the programmer and are available in Python Project.
# * These exceptions were used to deal with common Problems,They are,
#   * a) Attempting to enter invalid PIN in atm applicatioins.
#   * b) Attempting to enter Wrong User Name and Password.
#   * c) Attempting to withdraw Invalid amount from existing account
#   * ...etc
#
# * Every **Valid Input** given **Successful Output**
# * Every **Invalid input** given **Exceptions**

# %% [markdown]
# ### <font color='#3498DB'>**Handling the Exceptions in Python**</font>

# %% [markdown]
# * Handling Exception means converting "**Technical Error Message**" into "**User Friendly Error Message**"
# * To convert  "**Technical Error Message**" into "**User Friendly Error Message**", we have 5 Keywords. They are,
#     1. <font color='#009900'>**try**</font>
#     2. <font color='#009900'>**except**</font>
#     3. <font color='#009900'>**else**</font>
#     4. <font color='#009900'>**finally**</font>
#     5. <font color='#009900'>**raise**</font>

# %% [markdown]
# ### <font color='#3498DB'>Syntax for handling Exceptions</font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Syntax:</b><br>
# <code><b>
# try:
#      Block of statements
#      Generating Exceptions
# except  <exception-class-name-1>:
#       Block of statements
#       generating User-Friendly Error Messages
# except  <exception-class-name-2>:
#       Block of statements
#       generating User-Friendly Error Messages
# -------------------------------------------
# except  <exception-class-name-n>:
#       Block of statements
#       generating User-Friendly Error Messages
# else:
#       Block of statements
#       generating Result of the Program
#  finally:
#       Block of statements
#       executed by PVM Compulsorily
# </b></code>
#
# </div>

# %% [markdown]
# ### <font color='#3498DB'>**Explanation for the keywords used in Syntax for handling the exceptions**</font>

# %% [markdown]
# 1. <font color='#009900'>**try block:**</font>
#
#  * It is the block, in which we write block of statements generating exceptions. In otherwords what are all the statements are generating exceptions then those statements must be written in try block and hence try block is called **exception monitering block**.
#  * When the exception occurs  in try block then PVM comes out of try block and excecutes appropriate except block.
#  * When the pvm executes appropriate except block, PVM never goes to try block for executing rest of the statements in try block.
#  * Every **try block must be immediately followed by except block**(Otherwise we get error).
#  * Every try block **must contain atleast one except block** and it is recommeded to write multiple except blocks for generating multiple user-frinedly error messages.
# ---
#
# 2. <font color='#009900'>**except block:**</font>
#
# * It is the block, in which write **Block of statements generating User-Friendly Error Messages**. In otherwords, **except block supresses the technical error messages and generates user-friendly error Messages** and except block is called **Exception Processing Block**.
# > Note:- **Handling the Exception = try block + except block**.
# * except block will execute when there is an exception occurs in try block.
# * Even though we write multiple except blocks, at any point of time only appropriate except block will execute depends on type of exception occurs in try block.
# * The place of writing except block is **after try block and before else block**(if we wrirte else block).
# ---
#
# 3. <font color='#009900'>**else block:**</font>
#
# * It is the block, In which we write **block of statements generating Result of the program**
# * else block will **execute when there is no exception exception occurs in try block**
# * Writing **else block is optional**
# * we write else block **after except block and before finally block**(if we write finally block)
# ---
#
# 4. <font color='#009900'>**finally block:**</font>
#
# * It is the block, in which we write **block of statements relinquish (release / close / give-up/ clean-up) the resources ( Files/ Database) which are obtained in try block**.
# * finally block **will execute compulsorily irrespective of type of exception occurs or not**
# * Writing finally block is **optional**.
# * finally block **to be written after else block**
# ---

# %% [markdown]
# ### <font color='#3498DB'>**Various forms of except blocks**</font>

# %% [markdown]
# #### <font color='#3498DB'>**Form-1 (Handling One Exception at a time)**</font>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <code><b>`try:
#     blcok of statements
#     generating exceptions
# except <Exception-Class-Name>
#     Block of statements
#     generating user frinedly error Messages`
# </b><code>
# </div>

# %% [markdown]
# ##### Example1

# %%
# Example of Form 1: Handling One Exception at a time
try:
    s1 = input("Enter the value of a : ")
    s2 = input("Enter the value of b : ")
    a = int(s1)
    b = int(s2)
    c = a / b
except ZeroDivisionError:
    print("\nDivision by Zero is not allowed. Dont enter zero for denominator!..")
except ValueError:
    print("\nDon't Enter string, symbols or alpha numeric values")
else:
    print("The value of a is: {}".format(a))
    print("The value of b is: {}".format(b))
    print("The Division Result is: {}".format(c))
finally:
    print("Thank you for using the application!")

# %% [markdown]
# #### <font color='#3498DB'>**Form-2 (Handling Multiple Exception at a time--multi exception handling block)**</font>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <code><b>
# try:
#     blcok of statements
#     generating exceptions
# except (exception class name-1, exception class name-2.. exception class name-n)
#     Block of statements
#     generating user frinedly error Messages
# </b></code>
# </div>

# %% [markdown]
# ##### Example2

# %%
# Example of Form 2: Handling Multiple Exception at a time--multi exception handling block
try:
    s1 = input("Enter the value of a : ")
    s2 = input("Enter the value of b : ")
    a = int(s1)
    b = int(s2)
    c = a / b
except (ZeroDivisionError, ValueError):
    print("\nDivision by Zero is not allowed. Dont enter zero for denominator!..")
    print("\nDon't Enter string, symbols or alpha numeric values")
else:
    print("The value of a is: {}".format(a))
    print("The value of b is: {}".format(b))
    print("The Division Result is: {}".format(c))
finally:
    print("Thank you for using the application!..")

# %% [markdown]
# #### <font color='#3498DB'>**Form-3:  (Handling Multiple Exception with alias name)**</font>

# %% [markdown]
# - With this Syntax, we are obtaining messages causing due to exception occurence

# %% [markdown]
# <div class="alert alert-block alert-success">
# <code><b>try:
#     blcok of statements
#     generating exceptions
# except <Exception-Class-Name-1> as <alias-name-1>
#     Block of statements
#     generating user frinedly error Messages
# except <Exception-Class-Name-2> as <alias-name-2>
#     Block of statements
#     generating user frinedly error Messages
# .
# .
# .
# except <Exception-Class-Name-n> as <alias-name-n>
#     Block of statements
#     generating user frinedly error Messages
# </b></code>
# </div>

# %% [markdown]
# ##### Example3

# %%
# Example of Form 3: Handling Multiple Exception with alias name

try:
    s1 = input("Enter the value of a : ")
    s2 = input("Enter the value of b : ")
    a = int(s1)
    b = int(s2)
    c = a / b
except ZeroDivisionError as k:
    print(k)
except ValueError as v:
    print(v)
else:
    print("The value of a is: {}".format(a))
    print("The value of b is: {}".format(b))
    print("The Division Result is: {}".format(c))
finally:
    print("Thank you for using the application!")

# %% [markdown]
# #### <font color='#3498DB'>**Form-4:  (Handling Multiple Exceptions with deafult except block)**</font>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <code><b>try:
#     blcok of statements
#     generating exceptions
# except_:
#     Block of statements
#     generating user frinedly error Messages
# </b></code>
# </div>
#
# - The except block can be with or without underscore(**except:** OR **except_:**)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip/Note:</b></br>
#     Industry is always <b>recommended to write default except block after specific except blocks</b> but not before spefic except blocks.
# </div>

# %% [markdown]
# ##### Example4

# %%
# Example of Form 4: Handling Multiple Exceptions with deafult except block

try:
    s1 = input("Enter the value of a : ")
    s2 = input("Enter the value of b : ")
    a = int(s1)
    b = int(s2)
    c = a / b
    s="PYTHON"
    print(s[10])
except ZeroDivisionError:
    print("\nDivision by Zero is not allowed. Dont enter zero for denominator!..")
except ValueError:
    print("\nDon't Enter string, symbols or alpha numeric values")
except:
    print("Exception Occurred: Something went wrong!..")
else:
    print("The value of a is: {}".format(a))
    print("The value of b is: {}".format(b))
    print("The Division Result is: {}".format(c))
finally:
    print("Thank you for using the application!")
# Out:
# Enter the value of a : 10
# Enter the value of b : 2
# Exception Occurred: Something went wrong!..
# Thank you for using the application!

# %% [markdown]
# #### <font color='#3498DB'>**Form-5:(Handling Multiple Exceptions with Base class exception)**</font>

# %% [markdown]
# - **Exception Handling Heirarchey Chart**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <code><b>try:
#     blcok of statements
#     generating exceptions
# except BaseException  :
#     Block of statements
#     generating user frinedly error Messages
# </b></code>
# </div>
#
# - <font color='#800000'>The except block can be declared as **BaseException** or simply **Exception**</code>

# %% [markdown]
# ##### Example5

# %%
# Example of Form 4: Handling Multiple Exceptions with deafult except block

try:
    s1 = input("Enter the value of a : ")
    s2 = input("Enter the value of b : ")
    a = int(s1)
    b = int(s2)
    c = a / b
    s="PYTHON"
    print(s[10])
except ZeroDivisionError:
    print("\nDivision by Zero is not allowed. Dont enter zero for denominator!..")
except ValueError:
    print("\nDon't Enter string, symbols or alpha numeric values")
except BaseException:
    print("Exception Occurred: Something went wrong!..")
else:
    print("The value of a is: {}".format(a))
    print("The value of b is: {}".format(b))
    print("The Division Result is: {}".format(c))
finally:
    print("Thank you for using the application!")

# %% [markdown]
# ### <font color='#3498DB'>**Development of Programmer / User / Custom-defined Exceptions.**</font>

# %% [markdown]
# - These exceptions developed by Programmer and they are avalible in Python Project and they used for dealing with Common Problems.
# - Some of the Common Problems are</br>
#     * Attempting to enter invalid PIN in atm applicatioins.</br>
#     * Attempting to enter Wrong User Name and Password.</br>
#     * Attempting to withdraw Invalid amount from existing account.. etc</br>
# - Every **Valid Input** gives **successful output**
# - Every **Invalid Input** gives **Exceptions.**
#
#
# #####  <font color='#3498DB'>**Steps for developing Programmer-defined Exceptions:**</font>
#
# - Choose the **Programmer-Defined Class Name**
# - The *Programmer-Defined Class Name* <font color='#009900'>**must inherit Either from "Exception"  or "BaseException"**</font> for obtaining exception handling features.
# - Save the above development on some filename with an extension .py ( treated as module name)
#
#
# ##### Examples:
#
# > Save file with the ".py" extension. This file name treated as module name(Exception Module) **pin.py**
#
# <div class="alert alert-block alert-success">
# <code><b>
# pin.py----------(3)
#             (1)           (2)
# class PinError(Exception):pass
# </b></code>
# </div>
#
#
#
# ##### Examples:
#
# > Save file with the ".py" extension. This file name treated as module name(Exception Module) **login.py**
#
# <div class="alert alert-block alert-success">
# <code><b>
# login.py--------(3)
#             (1)                 (2)
# class LoginError(BaseException):pass
# </b></code>
# </div>
#
#
# #####  <font color='#3498DB'>**We follow 3 phases for development of Programmer-defined exception. They are**</font>
#
# *  <font color='#009900'>**Develop Programmer-defined Exception classes**</font>
# * <font color='#009900'>**Hit / Generate the Programer-defined Exceptions (raise )**</font>
# * <font color='#009900'>**Handle the Programmer-defined exceptions(try,except, else, finally)**</font>

# %% [markdown]
# #### <font color='#3498DB'>**raise keyword**</font>

# %% [markdown]
# * **raise** keyword is used for hitting / raising / generating the exception when certain condition is satisfied.
# * PVM uses raise keyword for hitting Pre-defined exceptions automatically. where as programmer makes the PVM  to use raise keyword  to hit programmer-defined exceptions when certain condition is satisfied.
#
#
# **Syntax**
#
# <div class="alert alert-block alert-success">
# <code><b>
# if(test cond):
#     raise exception-class-name
# </b></code>
# </div>
#
# <div class="alert alert-block alert-success">
# <code><b>
# def   function-name(list of formal params if any):
#     if(test cond):
#         raise exception-class-name
# </b></code>
# </div>

# %% [markdown]
# ##### Case Study 1
# <font color='#D2691E'>**Qn) Develop a programmer defined exception for dealing with Division by Zero problems**</font>
#
# **OR**
#
# <font color='#D2691E'>**Develop a programmer defined exception it should work like ZeroDivisionError(Pre Defined Exception)**</font>

# %% [markdown]
# ##### Example 1 : Everything in single file

# %%
# Phase 1 Development Programmer-defined Exception

class DivexDivisionError(Exception): pass


# Phase 2  Hitting the exception by using raise keyword

def division(a, b):
    if (b == 0):
        raise DivexDivisionError  # Hitting or generating programmer defined exception
    else:
        c = a / b
        return c


# Phase 3 -- Handling the exceptions by using try and except keywords

try:
    a = int(input("Enter the value of a:"))
    b = int(input("Enter the value of b :"))
    result = division(a, b)
except DivexDivisionError:
    print("\nDont enter zero for denominator..")
except ValueError:
    print("\n Don't enter strings or alphanumeric or symbols")
else:
    print("Division result:  {} / {} = {}".format(a, b, result))
finally:
    print("\nThanks for using this Application")

# %% [markdown]
# ##### Example 2: Using seperate modules(Like in Realtime project)

# %%
# Phase 1 Development Programmer-defined Exception
# divex1.py -- > File name treated as module name

class DivexDivisionError(Exception): pass

# %%
# Phase 2  Hitting the exception by using raise keyword
# divop.py  -- > File name treated as module name

from divex1 import DivexDivisionError


def division(a, b):
    if (b == 0):
        raise DivexDivisionError  # Hitting or generating programmer defined exception
    else:
        c = a / b
        return c

# %%
# Phase 3 -- Handling the exceptions by using try and except keywords

from divop import division
from divex1 import DivexDivisionError

try:
    a = int(input("Enter the value of a:"))
    b = int(input("Enter the value of b :"))
    result = division(a, b)
except DivexDivisionError:
    print("\nDont enter zero for denominator..")
except ValueError:
    print("\n Don't enter strings or alphanumeric or symbols")
else:
    print("Division result:  {} / {} = {}".format(a, b, result))
finally:
    print("\nThanks for using this Application")

# %% [markdown]
# ##### Case Study 2
# <font color='#D2691E'>**Qn)Write a python program which will accept a positive numerical value and generate multiplication table.**</font>
#
# **AND**
#
# <font color='#D2691E'>**Qn)If the number is negative or zero, we must hit and handle the exception.**</font>

# %%
# Phase 1
# invalid.py -- filename/modulename

class InvalidInput(BaseException): pass

# %%
# Phase 2

from invalid import InvalidInput


def table(a):
    if (a <= 0):
        raise InvalidInput  # Hitting the exception
    else:
        print("-" * 50)
        print("Multiplication table of {} is:\n".format(a))
        print("-" * 50)
        for i in range(1, 11):
            print("{} * {} = {}".format(i, a, i * a))
        print("-" * 50)

# %%
# Phase 3

from multable import table
from invalid import InvalidInput

try:
    n = int(input("Enter the value of n:"))
    table(n)
except ValueError:
    print("\nStrings/symbols/alpha-numeric are not supported")
except InvalidInput:
    print("\nEnter a valid Positive Integer greater than Zero")
finally:
    print("\nThanks for using this application!..")
